# %% [markdown]
# # Latihan 1: Bitcoin Price

# %% [markdown]
# ## Analisis Harga Bitcoin 2018 vs 2019
#
# Kita memiliki daftar harga **Bitcoin** yang dicatat setiap akhir minggu (**hari Minggu**) pada tahun **2018** dan **2019**.
#
# ### Tujuan:
# Buat visualisasi yang memungkinkan Anda menjawab pertanyaan:
#
# > **Tahun apa, 2018 atau 2019, yang cenderung memberikan pengembalian yang lebih baik bagi pemegang Bitcoin?**
#
# Gunakan data mingguan ini untuk membandingkan performa Bitcoin dari kedua tahun tersebut secara visual.

# %%
import matplotlib.pyplot as plt

# Data harga Bitcoin mingguan dari tahun 2018 dan 2019 (total 104 minggu)
prices = [14292.2, 12858.9, 11467.5, 9241.1, 8559.6, 11073.5, 9704.3, 11402.3,
          8762.0, 7874.9, 8547.4, 6938.2, 6905.7, 8004.4, 8923.1, 9352.4,
          9853.5, 8459.5, 8245.1, 7361.3, 7646.6, 7515.8, 6505.8, 6167.3, 
          6398.9, 6765.5, 6254.8, 7408.7, 8234.1, 7014.3, 6231.6, 6379.1,
          6734.8, 7189.6, 6184.3, 6519.0, 6729.6, 6603.9, 6596.3, 6321.7,
          6572.2, 6494.2, 6386.2, 6427.1, 5621.8, 3920.4, 4196.2, 3430.4,
          3228.7, 3964.4, 3706.8, 3785.4, 3597.2, 3677.8, 3570.9, 3502.5,
          3661.4, 3616.8, 4120.4, 3823.1, 3944.3, 4006.4, 4002.5, 4111.8,
          5046.2, 5051.8, 5290.2, 5265.9, 5830.9, 7190.3, 7262.6, 8027.4,
          8545.7, 7901.4, 8812.5, 10721.7, 11906.5, 11268.0, 11364.9, 10826.7,
          9492.1, 10815.7, 11314.5, 10218.1, 10131.0, 9594.4, 10461.1, 10337.3,
          9993.0, 8208.5, 8127.3, 8304.4, 7957.3, 9230.6, 9300.6, 8804.5,
          8497.3, 7324.1, 7546.6, 7510.9, 7080.8, 7156.2, 7321.5, 7376.8]

# Minggu ke-1 sampai ke-52 adalah tahun 2018, sisanya tahun 2019
weeks_2018 = list(range(1, 53))
weeks_2019 = list(range(1, 53))

prices_2018 = prices[:52]
prices_2019 = prices[52:]

# Membuat Line Chart
plt.figure(figsize=(12, 6))
plt.plot(weeks_2018, prices_2018, label='2018', color='orange', linewidth=2)
plt.plot(weeks_2019, prices_2019, label='2019', color='green', linewidth=2)

# Menambahkan judul dan label
plt.title('Harga Bitcoin Mingguan: 2018 vs 2019', fontsize=14)
plt.xlabel('Minggu ke-', fontsize=12)
plt.ylabel('Harga (USD)', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()

# Tampilkan grafik
plt.show()
